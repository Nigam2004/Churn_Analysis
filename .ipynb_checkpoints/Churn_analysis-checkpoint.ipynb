# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlite3

# %%
##connevtion with DB
conn = sqlite3.connect('customer_churn.db')
sql_query="""
 SELECT name FROM sqlite_master WHERE type='table';
"""
tables= pd.read_sql(sql_query,conn)
##Create dataDrame for each Table
for table_name in tables['name']:
    df=pd.read_sql(f"Select * from {table_name}", conn)
    globals()[f"df_{table_name}"]=df
    print(f"created df:df_{table_name}")
conn.close()
# Out:
# created df:df_db_customer
# created df:df_db_subscription
# created df:df_db_support

# %%
df_db_customer.columns
# Out:
# Index(['customerid', 'name', 'country', 'state', 'gender', 'dob', 'interests',
#        'pincode'],
#       dtype='str')

# %%
df_db_subscription.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score'],
#       dtype='str')

# %%
df_db_support.columns
# Out:
# Index(['customerid', 'complaint_date', 'escalations', 'csat_score', 'col_1',
#        'comment'],
#       dtype='str')

# %%
##Data Cleaning of all tables

# %% [markdown]
# Cleaning of Customer Table

# %%
df_db_customer.head()
# Out:
#    customerid    name country        state  gender                  dob  \
# 0  0002-ORFBO  keshav   India  Maharashtra    Male  1982-04-12 00:00:00
# 1  0003-MKNFE  raghav   India    Karnataka    Male  1995-11-23 00:00:00
# 2  0004-TLHLJ  lalita   India        Delhi  Female  1978-02-15 00:00:00
# 3  0011-IGKFF   mohan   India     Nagaland    Male  2001-08-30 00:00:00
# 4  0013-EXCHZ    mira   India        Delhi  Female  1990-05-05 00:00:00
#
#   interests pincode
# 0    travel    None
# 1       NaN    None
# 2     movie    None
# 3       NaN    None
# 4     drama    None

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  21 non-null     str
#  1   name        21 non-null     str
#  2   country     18 non-null     str
#  3   state       21 non-null     str
#  4   gender      21 non-null     str
#  5   dob         21 non-null     str
#  6   interests   4 non-null      str
#  7   pincode     0 non-null      object
# dtypes: object(1), str(7)
# memory usage: 1.4+ KB

# %%
df_db_customer.rename(columns={'name':'Customer_name'},inplace=True)

# %%
##Drop columns
##df_db_customer.drop(df_db_customer.columns[-2:],axis=1,)
df_db_customer.drop(columns=['interests','pincode'],inplace=True)

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     21 non-null     str
#  1   Customer_name  21 non-null     str
#  2   country        18 non-null     str
#  3   state          21 non-null     str
#  4   gender         21 non-null     str
#  5   dob            21 non-null     str
# dtypes: str(6)
# memory usage: 1.1 KB

# %%
## Change the dob columns datatype to DateTime
df_db_customer['dob']=pd.to_datetime(df_db_customer['dob'])

# %%
##Replace the gender column
df_db_customer['gender']=df_db_customer['gender'].replace({'Men':'Male','Women':'Female'})

# %%
df_db_customer
# Out:
#     customerid Customer_name country          state  gender        dob
# 0   0002-ORFBO        keshav   India    Maharashtra    Male 1982-04-12
# 1   0003-MKNFE        raghav   India      Karnataka    Male 1995-11-23
# 2   0004-TLHLJ        lalita   India          Delhi  Female 1978-02-15
# 3   0011-IGKFF         mohan   India       Nagaland    Male 2001-08-30
# 4   0013-EXCHZ          mira   India          Delhi  Female 1990-05-05
# 5   0013-MHZWF         durga     NaN          Delhi  Female 1988-12-10
# 6   0013-SMEOE          mina   India      Meghalaya  Female 1976-09-21
# 7   0014-BMAQU         madan   India      Rajasthan    Male 1999-03-14
# 8   0015-UOCOJ          maya     NaN      Kathmandu  Female 1985-07-07
# 9   0016-QLJIS         arjun   Nepal      Kathmandu    Male 1993-10-29
# 10  0017-DINOC         shiva   India    Maharashtra    Male 1997-01-22
# 11  0017-IUDMW     rangadevi   India      Karnataka  Female 1981-06-18
# ...

# %%
## Fix missing values-countries
df_db_customer[df_db_customer['country'].isnull()]
# Out:
#     customerid Customer_name country      state  gender        dob
# 5   0013-MHZWF         durga     NaN      Delhi  Female 1988-12-10
# 8   0015-UOCOJ          maya     NaN  Kathmandu  Female 1985-07-07
# 12  0018-NYROU        chitra     NaN  Telangana  Female 2004-12-01

# %%
## df = df_db_customer.dropna(subset=['country']) --create a table without null value
## df = df.set_index('state')['country'].to_dict() --set the state as index and select the country and make it dictionary

state_country_mapping=df_db_customer.dropna(subset=['country']).set_index('state')['country'].to_dict()
state_country_mapping
# Out:
# {'Maharashtra': 'India',
#  'Karnataka': 'India',
#  'Delhi': 'India',
#  'Nagaland': 'India',
#  'Meghalaya': 'India',
#  'Rajasthan': 'India',
#  'Kathmandu': 'Nepal',
#  'Uttar Pradesh': 'India',
#  'Telangana': 'India'}

# %%
## its mapping all the values of state column and place the matching value 
df_db_customer['country']=df_db_customer['country'].fillna(df_db_customer['state'].map(state_country_mapping))

# %%
df_db_customer
# Out:
#     customerid Customer_name country          state  gender        dob
# 0   0002-ORFBO        keshav   India    Maharashtra    Male 1982-04-12
# 1   0003-MKNFE        raghav   India      Karnataka    Male 1995-11-23
# 2   0004-TLHLJ        lalita   India          Delhi  Female 1978-02-15
# 3   0011-IGKFF         mohan   India       Nagaland    Male 2001-08-30
# 4   0013-EXCHZ          mira   India          Delhi  Female 1990-05-05
# 5   0013-MHZWF         durga   India          Delhi  Female 1988-12-10
# 6   0013-SMEOE          mina   India      Meghalaya  Female 1976-09-21
# 7   0014-BMAQU         madan   India      Rajasthan    Male 1999-03-14
# 8   0015-UOCOJ          maya   Nepal      Kathmandu  Female 1985-07-07
# 9   0016-QLJIS         arjun   Nepal      Kathmandu    Male 1993-10-29
# 10  0017-DINOC         shiva   India    Maharashtra    Male 1997-01-22
# 11  0017-IUDMW     rangadevi   India      Karnataka  Female 1981-06-18
# ...

# %% [markdown]
# ---Customer Table cleaning Done

# %% [markdown]
# Cleaning of subscription table

# %%
df_db_subscription.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score'],
#       dtype='str')

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     str
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     str
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      str
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 1.9 KB

# %%
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaN                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaN                     NaN
# 3   Premium        Annual               NaN                     NaN
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score
# 0            13.99   627           12
# 1            12.99  1150           91
# ...

# %%
## change the datatype of all dated column in to Datetime
date_col=['subscription_start_date','renewal_date','cancellation_date']
df_db_subscription[date_col]=df_db_subscription[date_col].apply(pd.to_datetime)
df_db_subscription.info()
df_db_subscription
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     datetime64[us]
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     datetime64[us]
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      datetime64[us]
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: datetime64[us](3), float64(1), int64(2), str(5)
# memory usage: 1.9 KB
#     customerid subscription_start_date subscription_type renewal_date  \
# ...

# %% [markdown]
# --Data Cleanig Done for Subscription table

# %% [markdown]
# Cleaning of support table

# %%
df_db_support.columns
# Out:
# Index(['customerid', 'complaint_date', 'escalations', 'csat_score', 'col_1',
#        'comment'],
#       dtype='str')

# %%
df_db_support.info()

# %%
df_db_support.head()
# Out:
#    customerid       complaint_date escalations  csat_score col_1  \
# 0  0003-MKNFE  2024-08-28 00:00:00           N          60  None
# 1  0003-MKNFE  2024-08-28 00:00:00           Y          10  None
# 2  0013-EXCHZ  2024-01-20 00:00:00           Y          20  None
# 3  0013-MHZWF  2025-03-18 00:00:00           N          90  None
# 4  0013-SMEOE  2024-11-01 00:00:00           N          30  None
#
#              comment
# 0      service issue
# 1     demaned refund
# 2                NaN
# 3  guidance to renew
# 4                NaN

# %%
df_db_support.drop(columns={'col_1','comment'},inplace=True)

# %%
df_db_support
# Out:
#    customerid       complaint_date escalations  csat_score col_1  \
# 0  0003-MKNFE  2024-08-28 00:00:00           N          60  None
# 1  0003-MKNFE  2024-08-28 00:00:00           Y          10  None
# 2  0013-EXCHZ  2024-01-20 00:00:00           Y          20  None
# 3  0013-MHZWF  2025-03-18 00:00:00           N          90  None
# 4  0013-SMEOE  2024-11-01 00:00:00           N          30  None
# 5  0017-IUDMW  2024-04-10 00:00:00           Y          25  None
# 6  0019-EFAEP  2024-09-27 00:00:00           Y          30  None
# 7  0022-TCJCI  2024-09-13 00:00:00           Y          10  None
# 8  0022-TCJCI  2024-09-14 00:00:00           N          90  None
#
#              comment
# 0      service issue
# 1     demaned refund
# 2                NaN
# 3  guidance to renew
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8    received refund

# %%
df_db_support['complaint_date']=pd.to_datetime(df_db_support['complaint_date'])

# %%
df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      datetime64[us]
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
#  4   col_1           0 non-null      object
#  5   comment         4 non-null      str
# dtypes: datetime64[us](1), int64(1), object(1), str(3)
# memory usage: 564.0+ bytes

# %%
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score col_1            comment
# 0  0003-MKNFE     2024-08-28           N          60  None      service issue
# 1  0003-MKNFE     2024-08-28           Y          10  None     demaned refund
# 2  0013-EXCHZ     2024-01-20           Y          20  None                NaN
# 3  0013-MHZWF     2025-03-18           N          90  None  guidance to renew
# 4  0013-SMEOE     2024-11-01           N          30  None                NaN
# 5  0017-IUDMW     2024-04-10           Y          25  None                NaN
# 6  0019-EFAEP     2024-09-27           Y          30  None                NaN
# 7  0022-TCJCI     2024-09-13           Y          10  None                NaN
# 8  0022-TCJCI     2024-09-14           N          90  None    received refund

# %%
df_db_support['complaint_count']=df_db_support.groupby('customerid')['customerid'].transform('count')
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score col_1            comment  \
# 0  0003-MKNFE     2024-08-28           N          60  None      service issue
# 1  0003-MKNFE     2024-08-28           Y          10  None     demaned refund
# 2  0013-EXCHZ     2024-01-20           Y          20  None                NaN
# 3  0013-MHZWF     2025-03-18           N          90  None  guidance to renew
# 4  0013-SMEOE     2024-11-01           N          30  None                NaN
# 5  0017-IUDMW     2024-04-10           Y          25  None                NaN
# 6  0019-EFAEP     2024-09-27           Y          30  None                NaN
# 7  0022-TCJCI     2024-09-13           Y          10  None                NaN
# 8  0022-TCJCI     2024-09-14           N          90  None    received refund
#
#    complaint_count
# 0                2
# 1                2
# 2                1
# 3                1
# 4                1
# 5                1
# 6                1
# 7                2
# ...

# %%
df_db_support=df_db_support.sort_values('complaint_date').drop_duplicates('customerid', keep='last')

# %%
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score col_1            comment  \
# 2  0013-EXCHZ     2024-01-20           Y          20  None                NaN
# 5  0017-IUDMW     2024-04-10           Y          25  None                NaN
# 1  0003-MKNFE     2024-08-28           Y          10  None     demaned refund
# 8  0022-TCJCI     2024-09-14           N          90  None    received refund
# 6  0019-EFAEP     2024-09-27           Y          30  None                NaN
# 4  0013-SMEOE     2024-11-01           N          30  None                NaN
# 3  0013-MHZWF     2025-03-18           N          90  None  guidance to renew
#
#    complaint_count
# 2                1
# 5                1
# 1                2
# 8                2
# 6                1
# 4                1
# 3                1

# %% [markdown]
# --Data Cleanig Done for support table

# %% [markdown]
# FEATURE ENGINEERING

# %%
df_db_subscription.head(3)
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                     NaN
#
#    monthly_charges  cltv  churn_score
# 0            13.99   627           12
# 1            12.99  1150           91
# 2             6.99   210           34

# %%
## flag the churn row 
df_db_subscription['churn_flag']=np.where(df_db_subscription['cancellation_date'].notna(),1,0)

# %%
df_db_subscription.head(3)
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                     NaN
#
#    monthly_charges  cltv  churn_score  churn_flag
# 0            13.99   627           12           0
# 1            12.99  1150           91           1
# 2             6.99   210           34           0

# %%
df_db_subscription.shape
# Out:
# (21, 12)

# %%
## Merge all 3 table
df=(df_db_subscription
    .merge(df_db_customer, on='customerid',how='left')
    .merge(df_db_support, on='customerid',how='left') )

# %%
df
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 5   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 6   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 7   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 8   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 9   0016-QLJIS              2022-04-03           Organic   2025-04-03
# 10  0017-DINOC              2021-12-01           Organic   2025-12-01
# 11  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# ...

# %%
df.shape

# %%
df_db_subscription['customerid'].unique()
# Out:
# <StringArray>
# ['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', '0011-IGKFF', '0013-EXCHZ',
#  '0013-MHZWF', '0013-SMEOE', '0014-BMAQU', '0015-UOCOJ', '0016-QLJIS',
#  '0017-DINOC', '0017-IUDMW', '0018-NYROU', '0019-EFAEP', '0019-GFNTW',
#  '0020-INWCK', '0020-JDNXP', '0021-IKXGC', '0022-TCJCI', '0023-HGHWL',
#  '0023-UYUPN']
# Length: 21, dtype: str

# %%
df_db_customer['customerid'].unique()
# Out:
# <StringArray>
# ['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', '0011-IGKFF', '0013-EXCHZ',
#  '0013-MHZWF', '0013-SMEOE', '0014-BMAQU', '0015-UOCOJ', '0016-QLJIS',
#  '0017-DINOC', '0017-IUDMW', '0018-NYROU', '0019-EFAEP', '0019-GFNTW',
#  '0020-INWCK', '0020-JDNXP', '0021-IKXGC', '0022-TCJCI', '0023-HGHWL',
#  '0023-UYUPN']
# Length: 21, dtype: str

# %%
df_db_support['customerid'].unique()
# Out:
# <StringArray>
# ['0013-EXCHZ', '0017-IUDMW', '0003-MKNFE', '0022-TCJCI', '0019-EFAEP',
#  '0013-SMEOE', '0013-MHZWF']
# Length: 7, dtype: str

# %%
df_db_support['customerid'].size
# Out:
# 7

# %%
df.to_csv('exported_churn_data.csv', index=False)

# %% [markdown]
# DATA ANALYSIS

# %%
df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'Customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'col_1', 'comment',
#        'complaint_count'],
#       dtype='str')

# %%
## Churn rate percantage
churn_rate=df['churn_flag'].mean()*100
print('Churn_rate=',churn_rate.round(2),'%')
# Out:
# Churn_rate= 28.57 %

# %%
## retenstion rate
retention_rate=100-churn_rate
print('retention_rate=',retention_rate.round(2),'%')
# Out:
# retention_rate= 71.43 %

# %%
## churn percentage by plan_type
churn_by_plan_type=(df.groupby('plan_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_plt'))
print(churn_by_plan_type)
# Out:
#   plan_type  churn_rate_plt
# 0     Basic           60.00
# 1   Premium           14.29
# 2  Standard           22.22

# %%
## avaerage revenue per user(ARPU)
ARPU=df['monthly_charges'].mean()
print('ARPU=',round(ARPU,2))
# Out:
# ARPU= 18.85

# %%
##calculate tenures of user
today=pd.Timestamp.today()
df['tenures']=np.where(
    df['cancellation_date'].notna(),
    (df['cancellation_date']-df['subscription_start_date']).dt.days,
    (today-df['subscription_start_date']).dt.days
)
avg_tenure=df['tenures'].mean()
print('avg_tenure(days)=',avg_tenure.round(0))
# Out:
# avg_tenure(days)= 1545.0

# %%
df
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 5   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 6   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 7   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 8   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 9   0016-QLJIS              2022-04-03           Organic   2025-04-03
# 10  0017-DINOC              2021-12-01           Organic   2025-12-01
# 11  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# ...

# %%
df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'Customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'col_1', 'comment',
#        'complaint_count', 'tenures'],
#       dtype='str')

# %%
## Revenue at risk
Rev_at_risk=df[df['churn_flag']==1]['monthly_charges'].sum()
print("Revnue at rink(INR)=",Rev_at_risk)
# Out:
# Revnue at rink(INR)= 73.94

# %%
## average copmalint per user
avg_comp_count=df['complaint_count'].sum()/df['customerid'].count()
print("average copmalint per user=",avg_comp_count.round(2))
# Out:
# average copmalint per user= 0.43

# %%
## churn risk 
conditions=[
    (df['churn_score']<50),
    (df['churn_score']>=50) & (df['churn_score']<70),
    (df['churn_score']>70)
]
risk=['low','Medium','High']
df['churn_risk']=np.select(conditions,risk,default='Unknown')

# %%
df[["churn_score",'churn_risk']].head()
# Out:
#    churn_score churn_risk
# 0           12        low
# 1           91       High
# 2           34        low
# 3            8        low
# 4           88       High

# %% [markdown]
# --Data Analysis Done

# %% [markdown]
# Data Visualization using Matplotlib

# %%
df
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 5   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 6   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 7   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 8   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 9   0016-QLJIS              2022-04-03           Organic   2025-04-03
# 10  0017-DINOC              2021-12-01           Organic   2025-12-01
# 11  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# ...

# %%
##Data Visualization 
df_visual=df.copy()

# %%
df_visual['cancelation_month']=df_visual['cancellation_date'].dt.to_period('M')
churn_trend=df_visual[df_visual['churn_flag']==1].groupby('cancelation_month').size()
churn_trend
plt.figure(figsize=(9,4))
plt.plot(churn_trend.index.astype(str),churn_trend.values,color="green",marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('Month')
plt.title('Monthly churn trend')
plt.ylabel('churned_customer')
plt.show()

# %%
##churn by plan type
churn_plan=df_visual.groupby("plan_type")['churn_flag'].mean()
churn_plan
plt.figure(figsize=(9,4))
plt.bar(churn_plan.index,churn_plan.values,color="green")
plt.xlabel('Plan type')
plt.title('Plan Type churn values')
plt.ylabel('Avarage_values')
plt.show()

# %% [markdown]
# --Data Visualization using Matplotlib done

# %% [markdown]
# Data Visualization using seaborn

# %%
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'Customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenures', 'churn_risk', 'cancelation_month'],
#       dtype='str')

# %%
df_encode=df_visual[[ 'plan_type', 'contract_type',  'churn_score',
       'churn_flag','escalations',  'churn_risk']]
df_encode
order_mapping={
    'plan_type':['Basic','Standard','Premium'],
    'contract_type':['Monthly','Annual'],
    'churn_risk':['low','Medium','High'],
    'escalations':['Y','N']
}
for col ,order  in order_mapping.items():
    print(col,order)
    df_encode[col]=pd.Categorical(df_encode[col].astype('category'),categories= order,ordered=True).codes

sns.heatmap(df_encode.corr(),annot=True)
# Out:
# plan_type ['Basic', 'Standard', 'Premium']
# contract_type ['Monthly', 'Annual']
# churn_risk ['low', 'Medium', 'High']
# escalations ['Y', 'N']
# <Axes: >

# %%
df_encode
# Out:
#     plan_type  contract_type  churn_score  churn_flag  escalations  churn_risk
# 0           1              1           12           0           -1           0
# 1           2              1           91           1            0           2
# 2           0              0           34           0           -1           0
# 3           2              1            8           0           -1           0
# 4           1              0           88           1            0           2
# 5           1              1           22           0            1           0
# 6           0              0           79           1            1           2
# 7           2              1            5           0           -1           0
# 8           1              0           34           0           -1           0
# 9           0              1           41           0           -1           0
# 10          2              1           14           0           -1           0
# ...

# %%
sns.pairplot(df_encode)

# %%
##catplot/faceplot
sns.catplot(data=df_visual, x='plan_type',y='monthly_charges',hue='gender',col='churn_risk')

# %% [markdown]
# --visualization using seaborn Done
